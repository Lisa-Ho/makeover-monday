# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_excel("2020W3.xlsx", sheet_name='Sheet2')

# %%
df
# Out:
#           Age bracket     Group  Gender  (2008/09 - 2009/10)  \
# 0         1.5-3 years  Children     All                 12.1
# 1          4-10 years  Children     All                 14.7
# 2          4-10 years  Children    Male                 14.8
# 3          4-10 years  Children  Female                 14.6
# 4         11-18 years  Children     All                 15.9
# 5         11-18 years  Children    Male                 16.2
# 6         11-18 years  Children  Female                 15.6
# 7         19-64 years    Adults     All                 11.8
# 8         19-64 years    Adults    Male                 12.0
# 9         19-64 years    Adults  Female                 11.6
# 10  65 years and over    Adults     All                 10.9
# 11  65 years and over    Adults    Male                 10.6
# 12  65 years and over    Adults  Female                 10.1
# 13        65-74 years    Adults     All                  9.9
# ...

# %%
df["Age bracket"].unique()
# Out:
# array(['1.5-3 years', '4-10 years', '11-18 years', '19-64 years',
#        '65 years and over', '65-74 years', '75 years and over'],
#       dtype=object)

# %%
df[df["Age bracket"].isin(['4-10 years', '11-18 years', '19-64 years','65 years and over', ])]
# Out:
#           Age bracket     Group  Gender  (2008/09 - 2009/10)  \
# 1          4-10 years  Children     All                 14.7
# 2          4-10 years  Children    Male                 14.8
# 3          4-10 years  Children  Female                 14.6
# 4         11-18 years  Children     All                 15.9
# 5         11-18 years  Children    Male                 16.2
# 6         11-18 years  Children  Female                 15.6
# 7         19-64 years    Adults     All                 11.8
# 8         19-64 years    Adults    Male                 12.0
# 9         19-64 years    Adults  Female                 11.6
# 10  65 years and over    Adults     All                 10.9
# 11  65 years and over    Adults    Male                 10.6
# 12  65 years and over    Adults  Female                 10.1
#
#     (2010/11 - 2011/12)  (2012/13 - 2013/14)  (2014/15-2015/16)  \
# 1                  15.5                 14.0               13.5
# ...

# %%
date_names = [2010, 2012, 2014, 2016, 2019]

# %%
# =========
# Initialise Figure and define layout
fig, ax = plt.subplots(figsize=(10,9))
fig.set_facecolor("#f7f6f4")

plt.show()

# =======

plt.

# %%
#define figure size
fig, ax = plt.subplots(figsize=(13,6),layout='tight')
fig.patch.set_facecolor('white')


#adjust white space around subplots
plt.subplots_adjust(left=None, bottom=None, right=None, top=None, wspace=0.2, hspace=0.5)

#general title + footer
plt.suptitle("Total traffic volumes for each mode, Jan to Dec 2021", fontsize=16, x=0.02, y=1.06, ha='left')
plt.figtext(0.02,0.99, "7-day rolling average", fontsize=12, ha='left')
plt.figtext(0.02,-0.02, "Source: Vivacity Labs", fontsize=10, ha='left')
plt.figtext(0.02,-0.06, "Note: Only includes sensors with data for at least 360 days (n=117)", fontsize=10, ha='left')

# multiple bar plot
num=0
for column in data:
    num+=1
 
    # Find the right spot on the plot
    plt.subplot(2,4, num)
    
    # Plot (use bar, plot, fill_between depending on chart type)
    plt.plot(data.index, data[column],  color=main_cols[0],  
             linewidth=2, alpha=1, zorder = 2)    
    plt.fill_between(data.index, data[column],  color=main_cols[0],  
             linewidth=1.9, alpha=0.5, zorder = 3)  

    #yaxis
    plt.gca().set_ylim(ymin=0)
    plt.gca().yaxis.set_major_formatter(mpl.ticker.StrMethodFormatter('{x:,.0f}'))
    plt.tick_params(axis='y', length = 0, color = "#444444", labelsize=7)
    plt.grid(visible=True, axis='y', zorder=1, color = "#D3D3D3")
    
    #x-axis
    dtFmt = mdates.DateFormatter('%b') # define the formatting
    plt.gca().xaxis.set_major_formatter(dtFmt) # apply the format to the desired axis
    start = mdates.date2num(datetime.datetime(2021,1,1))
    end = mdates.date2num(datetime.datetime(2021,12,31))
    plt.xticks(np.arange(start,end,90))
   
    
    #remove frame outlines for each chart except bottom
    for pos in ['right', 'top',  'left']:
        plt.gca().spines[pos].set_visible(False)
 
    # Add title
    plt.title(column, loc='center', fontsize=12, fontweight=0.2, y=1.08)

plt.savefig(os.path.join(outputs, filename), bbox_inches='tight')
    
plt.show()

# %%
#function to draw arrows
def draw_arrow(plt, arr_start, arr_end):
       dx = arr_end[0] - arr_start[0]
       dy = arr_end[1] - arr_start[1]
       plt.arrow(arr_start[0], arr_start[1], dx, dy,
                 head_width=1, head_length=1, length_includes_head=True, color='black')

# %%
plt.xlim(-2,2)
plt.ylim(-2,2)
draw_arrow(plt, [0,0], [0,-1])
plt.show()
